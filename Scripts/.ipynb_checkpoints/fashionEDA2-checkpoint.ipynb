# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTagger
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud, STOPWORDS
from wordcloud import ImageColorGenerator
from plotnine import ggplot, aes, geom_line
import re
from pathlib import Path

# %% [markdown]
# ### Function Definitions

# %%
# Inches conversion function
def convert_to_inches(height):
    pattern = re.compile(r"(\d+)ft (\d+)in")  # Regular expression pattern to match feet and inches
    match = pattern.match(height)
    if match:
        feet = int(match.group(1))
        inches = int(match.group(2))
        total_inches = (feet * 12) + inches
        return total_inches
    else:
        return None

# %%
# Text analysis functions
def processText(text):
    text = text.str.replace("(<br/>)", "")
    text = text.str.replace('(<a).*(>).*(</a>)', '')
    text = text.str.replace('(&amp)', '')
    text = text.str.replace('(&gt)', '')
    text = text.str.replace('(&lt)', '')
    text = text.str.replace('(\xa0)', ' ')
    return text

# List out reviews based on polarity
def listPolarity(df, pol, col_name, n):
    col = df.loc[df.polarity == pol, [col_name]].sample(n).values
    for c in col:
        print(c[0])

# %% [markdown]
# ### Load Data

# %%
df = pd.read_json('../Data/modcloth/modcloth_final_data.json', lines=True)
df.head()
# Out:
#    item_id  waist  size  quality cup size  hips  bra size category bust
# 0   123373   29.0     7      5.0        d  38.0      34.0      new   36  \
# 1   123373   31.0    13      3.0        b  30.0      36.0      new  NaN
# 2   123373   30.0     7      2.0        b   NaN      32.0      new  NaN
# 3   123373    NaN    21      5.0     dd/e   NaN       NaN      new  NaN
# 4   123373    NaN    18      5.0        b   NaN      36.0      new  NaN
#
#     height         user_name         length    fit  user_id  shoe size
# 0  5ft 6in             Emily     just right  small   991571        NaN  \
# 1  5ft 2in  sydneybraden2001     just right  small   587883        NaN
# 2  5ft 7in             Ugggh  slightly long  small   395665        9.0
# 3      NaN      alexmeyer626     just right    fit   875643        NaN
# 4  5ft 2in        dberrones1  slightly long  small   944840        NaN
#
#   shoe width review_summary review_text
# 0        NaN            NaN         NaN
# 1        NaN            NaN         NaN
# 2        NaN            NaN         NaN
# 3        NaN            NaN         NaN
# 4        NaN            NaN         NaN

# %%
# Remove new, wedding, and sale from category
# Remove NAN review
df2 = df.loc[(df["category"] != "new") & (df["category"] != "wedding") & 
       (df["category"] != "sale")]
df2 = df2.loc[df["review_text"].isnull() == 0]

# %% [markdown]
# #### Convert height into inches

# %%
df2['height'] = df2['height'].astype(str)
df2['height_inches'] = df2['height'].apply(convert_to_inches)
df2.head()
# Out:
#       item_id  waist  size  quality cup size  hips  bra size category bust
# 8490   159891   26.0     1      5.0        a  38.0      32.0  dresses  NaN  \
# 8491   159891    NaN     8      4.0        c   NaN      34.0  dresses  NaN
# 8492   159891    NaN     8      5.0        b   NaN      32.0  dresses  NaN
# 8493   159891   31.0     8      3.0        d  41.0      36.0  dresses  NaN
# 8494   159891    NaN    12      3.0     dd/e  36.0      34.0  dresses  NaN
#
#        height  user_name      length  fit  user_id  shoe size shoe width
# 8490  5ft 4in   Isabella  just right  fit   240386        NaN        NaN  \
# 8491  5ft 8in    Hillary  just right  fit   531304        NaN        NaN
# 8492  5ft 2in  caitortot  just right  fit   460168        NaN        NaN
# 8493  5ft 2in   mercersg  just right  fit   439693        NaN        NaN
# 8494  5ft 5in       Erin  just right  fit   479187        NaN        NaN
#
#                  review_summary
# 8490  This dress. Is so amazing  \
# 8491  Best dress I've purchased
# 8492                     Lucky!
# 8493  This dress looks great on
# 8494  So adorable! The straps a
#
#                                             review_text  height_inches
# 8490  This dress. Is so amazing. It just arrived tod...           64.0
# 8491  Best dress I've purchased on this site! (and t...           68.0
# 8492  I managed to get this dress in my Stylish Surp...           62.0
# 8493  This dress looks great on. I'm a pretty curren...           62.0
# 8494  So adorable! The straps are adjustable, which ...           65.0

# %% [markdown]
# #### Add polarity scores

# %%
df2['review_text'] = processText(df2['review_text'])

df2['polarity'] = df2['review_text'].map(lambda txt: TextBlob(txt).sentiment.polarity)
df2['reviewLen'] = df2['review_text'].astype(str).apply(len)
df2['wordCount'] = df2['review_text'].apply(lambda x: len(str(x).split()))

# %%
print("Reviews with the highest positive sentiment polarity: ")
print("-----------------------------------------------------")
listPolarity(df2, 1, 'review_text', 5)
print("")
print("Reviews with most neutral sentiment polarity: ")
print("-----------------------------------------------")
listPolarity(df2, 0, 'review_text', 5)
print("")
print("Reviews with the highest negative sentiment polarity: ")
print("------------------------------------------------------")
listPolarity(df2, -1, 'review_text', 5)
# Out:
# Reviews with the highest positive sentiment polarity:
# -----------------------------------------------------
# Perfect dress for any day.. Nothing but compliments, if you are curvy like I am this will be should be a staple piece of your wardrobe
# Best gift from a friend. perfect for me
# The perfect lbd.
# Perfect!
# perfect for the occasion
#
# Reviews with most neutral sentiment polarity:
# -----------------------------------------------
# I'll be getting this blazer in different colors.
# Need in every color!
# .
# If I could. I would wear it every day
# It fits well and is one of my favorites
#
# Reviews with the highest negative sentiment polarity:
# ------------------------------------------------------
# Hated this fabric!
# terrible material.
# Horrible fabric and belt
# terrible material.  feels like plastic on skin.
# I have this skirt in two colours. don't ask me why because I look horrible in both. Tags are still on one of them. they are SO unflattering on my shape.

# %%
df2.head()
# Out:
#       item_id  waist  size  quality cup size  hips  bra size category bust
# 8490   159891   26.0     1      5.0        a  38.0      32.0  dresses  NaN  \
# 8491   159891    NaN     8      4.0        c   NaN      34.0  dresses  NaN
# 8492   159891    NaN     8      5.0        b   NaN      32.0  dresses  NaN
# 8493   159891   31.0     8      3.0        d  41.0      36.0  dresses  NaN
# 8494   159891    NaN    12      3.0     dd/e  36.0      34.0  dresses  NaN
#
#        height  ...  fit user_id shoe size  shoe width
# 8490  5ft 4in  ...  fit  240386       NaN         NaN  \
# 8491  5ft 8in  ...  fit  531304       NaN         NaN
# 8492  5ft 2in  ...  fit  460168       NaN         NaN
# 8493  5ft 2in  ...  fit  439693       NaN         NaN
# 8494  5ft 5in  ...  fit  479187       NaN         NaN
#
#                  review_summary
# 8490  This dress. Is so amazing  \
# 8491  Best dress I've purchased
# 8492                     Lucky!
# 8493  This dress looks great on
# 8494  So adorable! The straps a
#
#                                             review_text height_inches
# 8490  This dress. Is so amazing. It just arrived tod...          64.0  \
# 8491  Best dress I've purchased on this site! (and t...          68.0
# 8492  I managed to get this dress in my Stylish Surp...          62.0
# 8493  This dress looks great on. I'm a pretty curren...          62.0
# 8494  So adorable! The straps are adjustable, which ...          65.0
#
#       polarity  reviewLen  wordCount
# 8490  0.392500        301         58
# 8491  0.377778        319         63
# 8492  0.412500        712        138
# 8493  0.186250        273         57
# 8494  0.347500        166         27
#
# [5 rows x 22 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58501 entries, 8490 to 82789
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   item_id         58501 non-null  int64
#  1   waist           2097 non-null   float64
#  2   size            58501 non-null  int64
#  3   quality         58454 non-null  float64
#  4   cup size        54005 non-null  object
#  5   hips            39783 non-null  float64
#  6   bra size        54144 non-null  float64
#  7   category        58501 non-null  object
#  8   bust            8461 non-null   object
#  9   height          58501 non-null  object
#  10  user_name       58501 non-null  object
#  11  length          58477 non-null  object
#  12  fit             58501 non-null  object
#  13  user_id         58501 non-null  int64
#  14  shoe size       19941 non-null  float64
#  15  shoe width      13253 non-null  object
#  16  review_summary  58501 non-null  object
#  17  review_text     58501 non-null  object
#  18  height_inches   55687 non-null  float64
#  19  polarity        58501 non-null  float64
#  20  reviewLen       58501 non-null  int64
#  21  wordCount       58501 non-null  int64
# dtypes: float64(7), int64(5), object(10)
# memory usage: 10.3+ MB

# %%
df2.iloc[:, 0:8]
df2.iloc[:,]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-24-a8da8a3d98a3> in <module>
# ----> 1 df2.iloc[:, 0:8, 9]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1095             if self._is_scalar_access(key):
#    1096                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097             return self._getitem_tuple(key)
#    1098         else:
#    1099             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1592
#    1593     def _getitem_tuple(self, tup: tuple):
# -> 1594         tup = self._validate_tuple_indexer(tup)
#    1595         with suppress(IndexingError):
#    1596             return self._getitem_lowerdim(tup)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_tuple_indexer(self, key)
#     898         Check the key for valid keys across my indexer.
#     899         """
# --> 900         key = self._validate_key_length(key)
#     901         key = self._expand_ellipsis(key)
#     902         for i, k in enumerate(key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_key_length(self, key)
#     937                     raise IndexingError(_one_ellipsis_message)
#     938                 return self._validate_key_length(key)
# --> 939             raise IndexingError("Too many indexers")
#     940         return key
#     941
#
# IndexingError: Too many indexers

# %%
col_i = list(range(0,8))
col_i.extend([11,12, 16, 17, 18, 19, 20, 21])
df3 = df2.iloc[:, col_i]
df3.head()
# Out:
#       item_id  waist  size  quality cup size  hips  bra size category
# 8490   159891   26.0     1      5.0        a  38.0      32.0  dresses  \
# 8491   159891    NaN     8      4.0        c   NaN      34.0  dresses
# 8492   159891    NaN     8      5.0        b   NaN      32.0  dresses
# 8493   159891   31.0     8      3.0        d  41.0      36.0  dresses
# 8494   159891    NaN    12      3.0     dd/e  36.0      34.0  dresses
#
#           length  fit             review_summary
# 8490  just right  fit  This dress. Is so amazing  \
# 8491  just right  fit  Best dress I've purchased
# 8492  just right  fit                     Lucky!
# 8493  just right  fit  This dress looks great on
# 8494  just right  fit  So adorable! The straps a
#
#                                             review_text  height_inches
# 8490  This dress. Is so amazing. It just arrived tod...           64.0  \
# 8491  Best dress I've purchased on this site! (and t...           68.0
# 8492  I managed to get this dress in my Stylish Surp...           62.0
# 8493  This dress looks great on. I'm a pretty curren...           62.0
# 8494  So adorable! The straps are adjustable, which ...           65.0
#
#       polarity  reviewLen  wordCount
# 8490  0.392500        301         58
# 8491  0.377778        319         63
# 8492  0.412500        712        138
# 8493  0.186250        273         57
# 8494  0.347500        166         27

# %%
cols_lst = ["item_id", "category", "waist", "size", "quality", "cup size", "hips", "bra size",
           "height_inches", "length", "fit", "review_summary", "review_text", "polarity", "reviewLen", "wordCount"]

# %%
df3 = df3[cols_lst]

# %%
df3
# Out:
#        item_id   category  waist  size  quality cup size  hips  bra size
# 8490    159891    dresses   26.0     1      5.0        a  38.0      32.0  \
# 8491    159891    dresses    NaN     8      4.0        c   NaN      34.0
# 8492    159891    dresses    NaN     8      5.0        b   NaN      32.0
# 8493    159891    dresses   31.0     8      3.0        d  41.0      36.0
# 8494    159891    dresses    NaN    12      3.0     dd/e  36.0      34.0
# ...        ...        ...    ...   ...      ...      ...   ...       ...
# 82785   807722  outerwear    NaN     8      4.0        b   NaN      36.0
# 82786   807722  outerwear    NaN    12      5.0    ddd/f   NaN      34.0
# 82787   807722  outerwear    NaN    12      5.0   dddd/g  36.0      32.0
# 82788   807722  outerwear    NaN    12      4.0      NaN   NaN       NaN
# 82789   807722  outerwear    NaN     4      4.0        d  39.0      32.0
#
#        height_inches         length    fit             review_summary
# 8490            64.0     just right    fit  This dress. Is so amazing  \
# 8491            68.0     just right    fit  Best dress I've purchased
# 8492            62.0     just right    fit                     Lucky!
# 8493            62.0     just right    fit  This dress looks great on
# 8494            65.0     just right    fit  So adorable! The straps a
# ...              ...            ...    ...                        ...
# 82785           68.0     just right    fit               Cute jacket!
# 82786           65.0  slightly long  small   It's a beautiful jacket.
# 82787           64.0     just right    fit  I love this blazer. It is
# 82788           63.0     just right    fit  I love this blazer!! I wo
# 82789            NaN     just right    fit  I love this piece. I'm re
#
#                                              review_text  polarity  reviewLen
# 8490   This dress. Is so amazing. It just arrived tod...  0.392500        301  \
# 8491   Best dress I've purchased on this site! (and t...  0.377778        319
# 8492   I managed to get this dress in my Stylish Surp...  0.412500        712
# 8493   This dress looks great on. I'm a pretty curren...  0.186250        273
# 8494   So adorable! The straps are adjustable, which ...  0.347500        166
# ...                                                  ...       ...        ...
# 82785                                       Cute jacket!  0.625000         12
# 82786  It's a beautiful jacket. I love how it's knit ...  0.412143        110
# 82787  I love this blazer. It is a great office piece...  0.516667        130
# 82788  I love this blazer!! I wore it yesterday and g...  0.294063        109
# 82789       I love this piece. I'm really happy with it!  0.750000         44
#
#        wordCount
# 8490          58
# 8491          63
# 8492         138
# 8493          57
# 8494          27
# ...          ...
# 82785          2
# 82786         24
# 82787         27
# 82788         19
# 82789          9
#
# [58501 rows x 16 columns]

# %% [markdown]
# ### Change `length` values
#
# * "just right" -> 5
# * "slightly long" -> 4
# * "very long" -> 3
# * "slightly short" -> 2
# * "very short" -> 1

# %%
df3["length"].unique()
# Out:
# array(['just right', 'slightly long', 'very long', 'slightly short',
#        'very short', nan], dtype=object)

# %%
df3.loc[df3["length"] == "just right", "length"] = 5
df3.loc[df3["length"] == "slightly long", "length"] = 4
df3.loc[df3["length"] == "very long", "length"] = 3
df3.loc[df3["length"] == "slightly short", "length"] = 2
df3.loc[df3["length"] == "very short", "length"] = 1

# %% [markdown]
# #### Change `fit` values
#
# * "fit" -> 3
# * "small" -> 2
# * "large" -> 1

# %%
df3["fit"].unique()
# Out:
# array([3, 2, 1])

# %%
df3.loc[df3["fit"] == "fit", "fit"] = 3
df3.loc[df3["fit"] == "small", "fit"] = 2
df3.loc[df3["fit"] == "large", "fit"] = 1

# %%
# Convert to integers
df3["fit"] = df3["fit"].astype(int)
df3["length"] = df3["length"].astype('Int32')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58501 entries, 8490 to 82789
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   item_id         58501 non-null  int64
#  1   category        58501 non-null  object
#  2   waist           2097 non-null   float64
#  3   size            58501 non-null  int64
#  4   quality         58454 non-null  float64
#  5   cup size        54005 non-null  object
#  6   hips            39783 non-null  float64
#  7   bra size        54144 non-null  float64
#  8   height_inches   55687 non-null  float64
#  9   length          58477 non-null  Int32
#  10  fit             58501 non-null  int64
#  11  review_summary  58501 non-null  object
#  12  review_text     58501 non-null  object
#  13  polarity        58501 non-null  float64
#  14  reviewLen       58501 non-null  int64
#  15  wordCount       58501 non-null  int64
# dtypes: Int32(1), float64(6), int64(5), object(4)
# memory usage: 7.4+ MB

# %%
# Save df3 as new dataset
filepath = Path('../Data/fashion.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df3.to_csv(filepath)

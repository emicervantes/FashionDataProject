# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fashion2.csv')
df
# Out:
#       Unnamed: 0  item_id   category  waist  size  quality cup size  hips  \
# 0           8490   159891    dresses   26.0     1      5.0        a  38.0
# 1           8493   159891    dresses   31.0     8      3.0        d  41.0
# 2           8521   160625    dresses   32.0     5      5.0        a   NaN
# 3           8523   160625    dresses   32.0    11      4.0        d  43.0
# 4           8524   160625    dresses   28.0     7      5.0        b  32.0
# ...          ...      ...        ...    ...   ...      ...      ...   ...
# 2092       81349   806406  outerwear   44.0    32      5.0    ddd/f   NaN
# 2093       82014   806856  outerwear   28.0     8      5.0        d  36.0
# 2094       82654   807252  outerwear   30.0    20      5.0        b  39.0
# 2095       82655   807252  outerwear   27.0     8      4.0        b  31.0
# 2096       82720   807384  outerwear   38.0    26      5.0        c  50.0
#
#       bra size  height_inches  length  fit                review_summary  \
# ...

# %%
df.loc[df["review_text"].isnull() == 0]
# Out:
#       Unnamed: 0  item_id   category  waist  size  quality cup size  hips  \
# 0           8490   159891    dresses   26.0     1      5.0        a  38.0
# 1           8493   159891    dresses   31.0     8      3.0        d  41.0
# 2           8521   160625    dresses   32.0     5      5.0        a   NaN
# 3           8523   160625    dresses   32.0    11      4.0        d  43.0
# 4           8524   160625    dresses   28.0     7      5.0        b  32.0
# ...          ...      ...        ...    ...   ...      ...      ...   ...
# 2092       81349   806406  outerwear   44.0    32      5.0    ddd/f   NaN
# 2093       82014   806856  outerwear   28.0     8      5.0        d  36.0
# 2094       82654   807252  outerwear   30.0    20      5.0        b  39.0
# 2095       82655   807252  outerwear   27.0     8      4.0        b  31.0
# 2096       82720   807384  outerwear   38.0    26      5.0        c  50.0
#
#       bra size  height_inches  length  fit                review_summary  \
# ...

# %%
df2 = df.loc[(df["category"] != "new") & (df["category"] != "wedding") & 
       (df["category"] != "sale")]
df2 = df2.loc[df["review_text"].isnull() == 0]
df2
# Out:
#       Unnamed: 0  item_id   category  waist  size  quality cup size  hips  \
# 0           8490   159891    dresses   26.0     1      5.0        a  38.0
# 1           8493   159891    dresses   31.0     8      3.0        d  41.0
# 2           8521   160625    dresses   32.0     5      5.0        a   NaN
# 3           8523   160625    dresses   32.0    11      4.0        d  43.0
# 4           8524   160625    dresses   28.0     7      5.0        b  32.0
# ...          ...      ...        ...    ...   ...      ...      ...   ...
# 2092       81349   806406  outerwear   44.0    32      5.0    ddd/f   NaN
# 2093       82014   806856  outerwear   28.0     8      5.0        d  36.0
# 2094       82654   807252  outerwear   30.0    20      5.0        b  39.0
# 2095       82655   807252  outerwear   27.0     8      4.0        b  31.0
# 2096       82720   807384  outerwear   38.0    26      5.0        c  50.0
#
#       bra size  height_inches  length  fit                review_summary  \
# ...

# %%
df_sub = df2[['waist','hips','cup size','bra size','height_inches','size','fit']].copy()
df_sub
# Out:
#       waist  hips cup size  bra size  height_inches  size  fit
# 0      26.0  38.0        a      32.0           64.0     1    3
# 1      31.0  41.0        d      36.0           62.0     8    3
# 2      32.0   NaN        a      32.0           65.0     5    1
# 3      32.0  43.0        d      38.0           67.0    11    2
# 4      28.0  32.0        b      34.0           65.0     7    3
# ...     ...   ...      ...       ...            ...   ...  ...
# 2092   44.0   NaN    ddd/f      44.0           69.0    32    3
# 2093   28.0  36.0        d      34.0           66.0     8    3
# 2094   30.0  39.0        b      42.0           64.0    20    3
# 2095   27.0  31.0        b      38.0           66.0     8    3
# 2096   38.0  50.0        c      38.0            NaN    26    2
#
# [2097 rows x 7 columns]

# %%
def get_first(s):
    
    first = s.split('/')[0]
    
    return first

# %%
df_sub['cup size'] = df_sub['cup size'].apply(get_first)

# %%
df_sub['cup size'].unique()
df_sub = df_sub.loc[df_sub['cup size'] != "nan"]
df_sub['cup size'].unique()
# Out:
# array(['a', 'd', 'b', 'dd', 'c', 'ddd', 'h', 'dddd', 'aa', 'j', 'i', 'k'],
#       dtype=object)

# %%
def select_element(lst):
    return lst[1]
# Out:
# ['a']

# %%
df_top = df_sub[['waist','cup size','bra size', 'height_inches']].copy()
df_bottom = df_sub[['waist','hips']].copy()
df_dresses = df_sub[['waist','cup size','bra size','height_inches','hips']].copy()

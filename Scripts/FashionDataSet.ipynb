# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
df = pd.read_json('../Data/modcloth/modcloth_final_data.json', lines=True)
df
# Out:
#        item_id  waist  size  quality cup size  hips  bra size   category bust
# 0       123373   29.0     7      5.0        d  38.0      34.0        new   36  \
# 1       123373   31.0    13      3.0        b  30.0      36.0        new  NaN
# 2       123373   30.0     7      2.0        b   NaN      32.0        new  NaN
# 3       123373    NaN    21      5.0     dd/e   NaN       NaN        new  NaN
# 4       123373    NaN    18      5.0        b   NaN      36.0        new  NaN
# ...        ...    ...   ...      ...      ...   ...       ...        ...  ...
# 82785   807722    NaN     8      4.0        b   NaN      36.0  outerwear  NaN
# 82786   807722    NaN    12      5.0    ddd/f   NaN      34.0  outerwear  NaN
# 82787   807722    NaN    12      5.0   dddd/g  36.0      32.0  outerwear  NaN
# 82788   807722    NaN    12      4.0      NaN   NaN       NaN  outerwear  NaN
# 82789   807722    NaN     4      4.0        d  39.0      32.0  outerwear  NaN
#
#         height         user_name         length    fit  user_id  shoe size
# 0      5ft 6in             Emily     just right  small   991571        NaN  \
# 1      5ft 2in  sydneybraden2001     just right  small   587883        NaN
# 2      5ft 7in             Ugggh  slightly long  small   395665        9.0
# 3          NaN      alexmeyer626     just right    fit   875643        NaN
# 4      5ft 2in        dberrones1  slightly long  small   944840        NaN
# ...        ...               ...            ...    ...      ...        ...
# 82785  5ft 8in          Jennifer     just right    fit   727820        8.5
# 82786  5ft 5in             Kelli  slightly long  small   197040        NaN
# 82787  5ft 4in          elacount     just right    fit   102493        NaN
# 82788  5ft 3in      jennaklinner     just right    fit   756491        NaN
# 82789      6ft   maireadsteadman     just right    fit    78305        NaN
#
#       shoe width             review_summary
# 0            NaN                        NaN  \
# 1            NaN                        NaN
# 2            NaN                        NaN
# 3            NaN                        NaN
# 4            NaN                        NaN
# ...          ...                        ...
# 82785    average               Cute jacket!
# 82786        NaN   It's a beautiful jacket.
# 82787        NaN  I love this blazer. It is
# 82788        NaN  I love this blazer!! I wo
# 82789        NaN  I love this piece. I'm re
#
#                                              review_text
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 82785                                       Cute jacket!
# 82786  It's a beautiful jacket. I love how it's knit ...
# 82787  I love this blazer. It is a great office piece...
# 82788  I love this blazer!! I wore it yesterday and g...
# 82789       I love this piece. I'm really happy with it!
#
# [82790 rows x 18 columns]

# %%
df.loc[df["review_text"].isnull() == 0]
# Out:
#        item_id  waist  size  quality cup size  hips  bra size   category bust
# 6725    152702   27.0     4      4.0        b  37.0      32.0        new  NaN  \
# 6726    152702   26.0     4      5.0        c  36.0      34.0        new  NaN
# 6727    152702    NaN     4      3.0        a   NaN      34.0        new  NaN
# 6728    152702   25.0     4      3.0        c  35.0      32.0        new  NaN
# 6729    152702   25.0     4      5.0        c  32.0      32.0        new  NaN
# ...        ...    ...   ...      ...      ...   ...       ...        ...  ...
# 82785   807722    NaN     8      4.0        b   NaN      36.0  outerwear  NaN
# 82786   807722    NaN    12      5.0    ddd/f   NaN      34.0  outerwear  NaN
# 82787   807722    NaN    12      5.0   dddd/g  36.0      32.0  outerwear  NaN
# 82788   807722    NaN    12      4.0      NaN   NaN       NaN  outerwear  NaN
# 82789   807722    NaN     4      4.0        d  39.0      32.0  outerwear  NaN
#
#         height        user_name          length    fit  user_id  shoe size
# 6725   5ft 6in            avNYC      just right  small   668176        9.0  \
# 6726   5ft 6in         lanwei91  slightly short    fit   320759        7.5
# 6727   5ft 3in  angeladevoe5678      just right    fit   144785        NaN
# 6728   5ft 1in             Juli   slightly long    fit    52664        NaN
# 6729   5ft 6in          lhalton      just right    fit   155439        NaN
# ...        ...              ...             ...    ...      ...        ...
# 82785  5ft 8in         Jennifer      just right    fit   727820        8.5
# 82786  5ft 5in            Kelli   slightly long  small   197040        NaN
# 82787  5ft 4in         elacount      just right    fit   102493        NaN
# 82788  5ft 3in     jennaklinner      just right    fit   756491        NaN
# 82789      6ft  maireadsteadman      just right    fit    78305        NaN
#
#       shoe width             review_summary
# 6725     average           Too much ruching  \
# 6726         NaN        Suits my body type!
# 6727         NaN  I love the design and fit
# 6728         NaN           Beautiful Dress!
# 6729         NaN  This is a very profession
# ...          ...                        ...
# 82785    average               Cute jacket!
# 82786        NaN   It's a beautiful jacket.
# 82787        NaN  I love this blazer. It is
# 82788        NaN  I love this blazer!! I wo
# 82789        NaN  I love this piece. I'm re
#
#                                              review_text
# 6725   I liked the color, the silhouette, and the fab...
# 6726   From the other reviews it seems like this dres...
# 6727   I love the design and fit of this dress!  I wo...
# 6728   I bought this dress for work  it is flattering...
# 6729   This is a very professional look. It is Great ...
# ...                                                  ...
# 82785                                       Cute jacket!
# 82786  It's a beautiful jacket. I love how it's knit ...
# 82787  I love this blazer. It is a great office piece...
# 82788  I love this blazer!! I wore it yesterday and g...
# 82789       I love this piece. I'm really happy with it!
#
# [76065 rows x 18 columns]

# %%
df2 = df.loc[(df["category"] != "new") & (df["category"] != "wedding") & 
       (df["category"] != "sale")]
df2 = df2.loc[df["review_text"].isnull() == 0]
df2
# Out:
#        item_id  waist  size  quality cup size  hips  bra size   category bust
# 8490    159891   26.0     1      5.0        a  38.0      32.0    dresses  NaN  \
# 8491    159891    NaN     8      4.0        c   NaN      34.0    dresses  NaN
# 8492    159891    NaN     8      5.0        b   NaN      32.0    dresses  NaN
# 8493    159891   31.0     8      3.0        d  41.0      36.0    dresses  NaN
# 8494    159891    NaN    12      3.0     dd/e  36.0      34.0    dresses  NaN
# ...        ...    ...   ...      ...      ...   ...       ...        ...  ...
# 82785   807722    NaN     8      4.0        b   NaN      36.0  outerwear  NaN
# 82786   807722    NaN    12      5.0    ddd/f   NaN      34.0  outerwear  NaN
# 82787   807722    NaN    12      5.0   dddd/g  36.0      32.0  outerwear  NaN
# 82788   807722    NaN    12      4.0      NaN   NaN       NaN  outerwear  NaN
# 82789   807722    NaN     4      4.0        d  39.0      32.0  outerwear  NaN
#
#         height        user_name         length    fit  user_id  shoe size
# 8490   5ft 4in         Isabella     just right    fit   240386        NaN  \
# 8491   5ft 8in          Hillary     just right    fit   531304        NaN
# 8492   5ft 2in        caitortot     just right    fit   460168        NaN
# 8493   5ft 2in         mercersg     just right    fit   439693        NaN
# 8494   5ft 5in             Erin     just right    fit   479187        NaN
# ...        ...              ...            ...    ...      ...        ...
# 82785  5ft 8in         Jennifer     just right    fit   727820        8.5
# 82786  5ft 5in            Kelli  slightly long  small   197040        NaN
# 82787  5ft 4in         elacount     just right    fit   102493        NaN
# 82788  5ft 3in     jennaklinner     just right    fit   756491        NaN
# 82789      6ft  maireadsteadman     just right    fit    78305        NaN
#
#       shoe width             review_summary
# 8490         NaN  This dress. Is so amazing  \
# 8491         NaN  Best dress I've purchased
# 8492         NaN                     Lucky!
# 8493         NaN  This dress looks great on
# 8494         NaN  So adorable! The straps a
# ...          ...                        ...
# 82785    average               Cute jacket!
# 82786        NaN   It's a beautiful jacket.
# 82787        NaN  I love this blazer. It is
# 82788        NaN  I love this blazer!! I wo
# 82789        NaN  I love this piece. I'm re
#
#                                              review_text
# 8490   This dress. Is so amazing. It just arrived tod...
# 8491   Best dress I've purchased on this site! (and t...
# 8492   I managed to get this dress in my Stylish Surp...
# 8493   This dress looks great on. I'm a pretty curren...
# 8494   So adorable! The straps are adjustable, which ...
# ...                                                  ...
# 82785                                       Cute jacket!
# 82786  It's a beautiful jacket. I love how it's knit ...
# 82787  I love this blazer. It is a great office piece...
# 82788  I love this blazer!! I wore it yesterday and g...
# 82789       I love this piece. I'm really happy with it!
#
# [58501 rows x 18 columns]

# %%
def convert_to_inches(height):
    pattern = re.compile(r"(\d+)ft (\d+)in")  # Regular expression pattern to match feet and inches
    match = pattern.match(height)
    if match:
        feet = int(match.group(1))
        inches = int(match.group(2))
        total_inches = (feet * 12) + inches
        return total_inches
    else:
        return None

# %%
df2['height'] = df2['height'].astype(str)
df2['height_inches'] = df2['height'].apply(convert_to_inches)
df2.head()
# Out:
#       item_id  waist  size  quality cup size  hips  bra size category bust
# 8490   159891   26.0     1      5.0        a  38.0      32.0  dresses  NaN  \
# 8491   159891    NaN     8      4.0        c   NaN      34.0  dresses  NaN
# 8492   159891    NaN     8      5.0        b   NaN      32.0  dresses  NaN
# 8493   159891   31.0     8      3.0        d  41.0      36.0  dresses  NaN
# 8494   159891    NaN    12      3.0     dd/e  36.0      34.0  dresses  NaN
#
#        height  user_name      length  fit  user_id  shoe size shoe width
# 8490  5ft 4in   Isabella  just right  fit   240386        NaN        NaN  \
# 8491  5ft 8in    Hillary  just right  fit   531304        NaN        NaN
# 8492  5ft 2in  caitortot  just right  fit   460168        NaN        NaN
# 8493  5ft 2in   mercersg  just right  fit   439693        NaN        NaN
# 8494  5ft 5in       Erin  just right  fit   479187        NaN        NaN
#
#                  review_summary
# 8490  This dress. Is so amazing  \
# 8491  Best dress I've purchased
# 8492                     Lucky!
# 8493  This dress looks great on
# 8494  So adorable! The straps a
#
#                                             review_text  height_inches
# 8490  This dress. Is so amazing. It just arrived tod...           64.0
# 8491  Best dress I've purchased on this site! (and t...           68.0
# 8492  I managed to get this dress in my Stylish Surp...           62.0
# 8493  This dress looks great on. I'm a pretty curren...           62.0
# 8494  So adorable! The straps are adjustable, which ...           65.0

# %%
df_sub = df2[['waist','hips','bust','height_inches']].copy()
df_sub
# Out:
#        waist  hips bust  height_inches
# 8490    26.0  38.0  NaN           64.0
# 8491     NaN   NaN  NaN           68.0
# 8492     NaN   NaN  NaN           62.0
# 8493    31.0  41.0  NaN           62.0
# 8494     NaN  36.0  NaN           65.0
# ...      ...   ...  ...            ...
# 82785    NaN   NaN  NaN           68.0
# 82786    NaN   NaN  NaN           65.0
# 82787    NaN  36.0  NaN           64.0
# 82788    NaN   NaN  NaN           63.0
# 82789    NaN  39.0  NaN            NaN
#
# [58501 rows x 4 columns]

# %%
df_sub2 = df2[['size']].copy()
df_sub2
# Out:
#        size
# 8490      1
# 8491      8
# 8492      8
# 8493      8
# 8494     12
# ...     ...
# 82785     8
# 82786    12
# 82787    12
# 82788    12
# 82789     4
#
# [58501 rows x 1 columns]

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/emicervantes/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>
